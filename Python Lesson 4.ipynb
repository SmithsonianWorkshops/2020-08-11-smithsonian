# %% [markdown]
# # Using plotnine package

# %%
# %matplotlib inline
import plotnine as p9

# %%
import pandas as pd

# %%
surveys_df = pd.read_csv("https://ndownloader.figshare.com/files/10717177")

# %%
surveys_complete = surveys_df.dropna()
surveys_complete
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 62            63      8   19  1977        3         DM   M             35.0
# 63            64      8   19  1977        7         DM   M             37.0
# 64            65      8   19  1977        4         DM   F             34.0
# 65            66      8   19  1977        4         DM   F             35.0
# 66            67      8   19  1977        7         DM   M             35.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35540      35541     12   31  2002       15         PB   F             24.0
# 35541      35542     12   31  2002       15         PB   F             26.0
# 35542      35543     12   31  2002       15         PB   F             27.0
# 35546      35547     12   31  2002       10         RM   F             15.0
# 35547      35548     12   31  2002        7         DO   M             36.0
#
#        weight
# 62       40.0
# 63       48.0
# ...

# %%
p9.ggplot(data=surveys_complete)
# Out:
# <ggplot: (274058355)>

# %%
p9.ggplot(data = surveys_complete, 
          mapping = p9.aes(x = "weight", y = "hindfoot_length"))
# Out:
# <ggplot: (297819757)>

# %%
p9.ggplot(data = surveys_complete,
         mapping = p9.aes(x = "weight", y = "hindfoot_length")) + p9.geom_point()
# Out:
# <ggplot: (297819850)>

# %%
surveys_plot = p9.ggplot(data = surveys_complete,
         mapping = p9.aes(x = "weight", y = "hindfoot_length"))

# %%
surveys_plot + p9.geom_point()
# Out:
# <ggplot: (297757275)>

# %%
surveys_plot + p9.geom_line()
# Out:
# <ggplot: (297768283)>

# %%
p9.ggplot(data = surveys_complete,
         mapping = p9.aes(x = "species_id")) + p9.geom_bar()
# Out:
# <ggplot: (298946554)>

# %%
p9.ggplot(data = surveys_complete,
         mapping = p9.aes(x = "plot_id")) + p9.geom_bar()
# Out:
# <ggplot: (298941169)>

# %%
(
    p9.ggplot(data = surveys_complete,
         mapping = p9.aes(x = "plot_id")) 
    + p9.geom_bar()
)
# Out:
# <ggplot: (296166572)>

# %%
(
surveys_plot 
    + p9.geom_point(alpha = 0.1, color = "red")
)
# Out:
# <ggplot: (298502132)>

# %%
(
p9.ggplot(data = surveys_complete,
         mapping = p9.aes(x = "weight",
                         y = "hindfoot_length",
                         color = "species_id"))
    + p9.geom_point(alpha = 0.1)
    + p9.xlab("Weight (g)")
    + p9.scale_x_log10()
    + p9.theme_bw()
    + p9.theme(text = p9.element_text(size = 16))
)
# Out:
# <ggplot: (297744999)>

# %%
# Out:
# <ggplot: (297540018)>

# %%
(
    p9.ggplot(data=surveys_complete, 
          mapping = p9.aes(x = 'plot_id', fill = 'sex')) 
+ p9.geom_bar()
)
# Out:
# <ggplot: (297745044)>

# %%
bar_plot = p9.ggplot(data = surveys_complete,
          mapping = p9.aes(x = "species_id", fill = "sex"))
(bar_plot +
p9.geom_bar() +
p9.theme_bw() +
p9.scale_y_log10())
# Out:
# <ggplot: (299359862)>

# %%
(bar_plot +
p9.geom_bar() +
p9.theme_xkcd() +
p9.scale_y_sqrt())
# Out:
# <ggplot: (298159987)>

# %%
(
p9.ggplot(data = surveys_complete,
          mapping = p9.aes(x = "species_id", 
                           y = "weight"))
    + p9.geom_jitter(alpha=0.2)
    + p9.geom_boxplot(alpha=0.05)
)
# Out:
# <ggplot: (297292376)>

# %%
(p9.ggplot(data = surveys_complete, 
           mapping = p9.aes(x = "species_id", y = "weight", color = "species_id")) 
 + p9.geom_jitter(alpha=0.2) 
 + p9.geom_violin(alpha=0.05, color = "black")
 + p9.scale_y_log10()
)
# Out:
# <ggplot: (296745247)>

# %%
my_plot = (
p9.ggplot(data = surveys_complete,
         mapping = p9.aes(x = "weight",
                         y = "hindfoot_length",
                         color = "species_id"))
    + p9.geom_point(alpha = 0.1)
    + p9.xlab("Weight (g)")
    + p9.scale_x_log10()
    + p9.theme_bw()
    + p9.theme(text = p9.element_text(size = 16))
    + p9.facet_wrap("sex")
)

# %%
my_plot.save("scatterplot.png", width = 10, height = 10, dpi = 300)
# Out:
# /Users/rteaching/opt/miniconda3/envs/data_ecology_workshop/lib/python3.8/site-packages/plotnine/ggplot.py:727: PlotnineWarning: Saving 10 x 10 in image.
# /Users/rteaching/opt/miniconda3/envs/data_ecology_workshop/lib/python3.8/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: scatterplot.png

# %%
# ?p9.ggplot.save
