# %% [markdown]
# # Python Lesson 2
# ## Starting with Data
# https://datacarpentry.org/python-ecology-lesson/02-starting-with-data/index.html

# %%
import pandas as pd

# %%
pd.read_csv("https://ndownloader.figshare.com/files/2292172")
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
surveys_df = pd.read_csv("https://ndownloader.figshare.com/files/2292172")

# %%
type(surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.head(2)
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
#
#    weight
# 0     NaN
# 1     NaN

# %%
surveys_df.tail(4)
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
surveys_df.sample(3)
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 23478      23479      2   25  1996        8         DO   M             34.0
# 1286        1287      9    4  1978       13         DS   F             48.0
# 6615        6616      9   19  1982       22         OL   M             20.0
#
#        weight
# 23478    37.0
# 1286    112.0
# 6615     26.0

# %%
surveys_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35549 entries, 0 to 35548
# Data columns (total 9 columns):
# record_id          35549 non-null int64
# month              35549 non-null int64
# day                35549 non-null int64
# year               35549 non-null int64
# plot_id            35549 non-null int64
# species_id         34786 non-null object
# sex                33038 non-null object
# hindfoot_length    31438 non-null float64
# weight             32283 non-null float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 2.4+ MB

# %%
surveys_df["record_id"]
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 35544    35545
# 35545    35546
# 35546    35547
# 35547    35548
# 35548    35549
# Name: record_id, Length: 35549, dtype: int64

# %%
surveys_df["weight"].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %% [markdown]
# # Come back at 11:05

# %% [markdown]
# Working through the SQL lesson (https://datacarpentry.org/sql-ecology-lesson/01-sql-basic-queries/index.html) using Pandas

# %%
surveys_df[["year","month","day"]]
# Out:
#        year  month  day
# 0      1977      7   16
# 1      1977      7   16
# 2      1977      7   16
# 3      1977      7   16
# 4      1977      7   16
# ...     ...    ...  ...
# 35544  2002     12   31
# 35545  2002     12   31
# 35546  2002     12   31
# 35547  2002     12   31
# 35548  2002     12   31
#
# [35549 rows x 3 columns]

# %%
surveys_df[["year","month","day"]].head(10)
# Out:
#    year  month  day
# 0  1977      7   16
# 1  1977      7   16
# 2  1977      7   16
# 3  1977      7   16
# 4  1977      7   16
# 5  1977      7   16
# 6  1977      7   16
# 7  1977      7   16
# 8  1977      7   16
# 9  1977      7   16

# %%
surveys_df["species_id"].unique()
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
surveys_df[["year","species_id"]].drop_duplicates()
# Out:
#        year species_id
# 0      1977         NL
# 2      1977         DM
# 5      1977         PF
# 6      1977         PE
# 10     1977         DS
# ...     ...        ...
# 34574  2002         UR
# 34778  2002         OL
# 35032  2002         SF
# 35510  2002         DX
# 35511  2002         US
#
# [535 rows x 2 columns]

# %%
surveys_df['weight'] / 1000
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 35544      NaN
# 35545      NaN
# 35546    0.014
# 35547    0.051
# 35548      NaN
# Name: weight, Length: 35549, dtype: float64

# %% [markdown]
# **Write a query that returns the year, month, day, species_id and weight for the last 10 rows**

# %%
surveys_df[["year","month","day", "species_id", "weight"]].tail(10)
# Out:
#        year  month  day species_id  weight
# 35539  2002     12   31         PB    23.0
# 35540  2002     12   31         PB    31.0
# 35541  2002     12   31         PB    29.0
# 35542  2002     12   31         PB    34.0
# 35543  2002     12   31         US     NaN
# 35544  2002     12   31         AH     NaN
# 35545  2002     12   31         AH     NaN
# 35546  2002     12   31         RM    14.0
# 35547  2002     12   31         DO    51.0
# 35548  2002     12   31        NaN     NaN

# %%
surveys_df['weight_kg'] = surveys_df['weight'] / 1000
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight  weight_kg
# 0     NaN        NaN
# 1     NaN        NaN
# 2     NaN        NaN
# 3     NaN        NaN
# 4     NaN        NaN

# %%
surveys_df.tail()
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight  weight_kg
# 35544     NaN        NaN
# 35545     NaN        NaN
# 35546    14.0      0.014
# 35547    51.0      0.051
# 35548     NaN        NaN

# %%
surveys_df['species_id'] == "DM"
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 35544    False
# 35545    False
# 35546    False
# 35547    False
# 35548    False
# Name: species_id, Length: 35549, dtype: bool

# %%
surveys_df[surveys_df['species_id'] == "DM"]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 2              3      7   16  1977        2         DM   F             37.0
# 3              4      7   16  1977        7         DM   M             36.0
# 4              5      7   16  1977        3         DM   M             35.0
# 7              8      7   16  1977        1         DM   M             37.0
# 8              9      7   16  1977        1         DM   F             34.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35532      35533     12   31  2002       14         DM   F             36.0
# 35533      35534     12   31  2002       14         DM   M             37.0
# 35534      35535     12   31  2002       14         DM   M             37.0
# 35535      35536     12   31  2002       14         DM   F             35.0
# 35536      35537     12   31  2002       14         DM   F             36.0
#
#        weight  weight_kg
# 2         NaN        NaN
# ...

# %%
surveys_df[surveys_df['year'] >= 2000].head()
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 30158      30159      1    8  2000        1         PP   F             22.0
# 30159      30160      1    8  2000        1         DO   M             35.0
# 30160      30161      1    8  2000        1         PP   F             21.0
# 30161      30162      1    8  2000        1         DM   M             36.0
# 30162      30163      1    8  2000        1         PP   M             20.0
#
#        weight  weight_kg
# 30158    17.0      0.017
# 30159    53.0      0.053
# 30160    17.0      0.017
# 30161    50.0      0.050
# 30162    16.0      0.016

# %%
dm_species = surveys_df['species_id'] == "DM"
surveys_df[dm_species].head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
#
#    weight  weight_kg
# 2     NaN        NaN
# 3     NaN        NaN
# 4     NaN        NaN
# 7     NaN        NaN
# 8     NaN        NaN

# %%
after_2000 = surveys_df['year'] >= 2000
surveys_df[dm_species & after_2000]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 30161      30162      1    8  2000        1         DM   M             36.0
# 30178      30179      1    8  2000       12         DM   M             36.0
# 30195      30196      1    8  2000       17         DM   M             37.0
# 30196      30197      1    8  2000       17         DM   F             34.0
# 30209      30210      1    8  2000       22         DM   M             38.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35532      35533     12   31  2002       14         DM   F             36.0
# 35533      35534     12   31  2002       14         DM   M             37.0
# 35534      35535     12   31  2002       14         DM   M             37.0
# 35535      35536     12   31  2002       14         DM   F             35.0
# 35536      35537     12   31  2002       14         DM   F             36.0
#
#        weight  weight_kg
# 30161    50.0      0.050
# ...

# %%
surveys_df[dm_species | after_2000]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# 7              8      7   16  1977        1         DM    M             37.0
# 8              9      7   16  1977        1         DM    F             34.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight  weight_kg
# ...

# %% [markdown]
# **Produce a table listing the data for all individuals in Plot 1 that weighed more than 75 grams**

# %%
weight_75 = surveys_df["weight"] > 75
plot1 = surveys_df["plot_id"] == 1
surveys_df[plot1 & weight_75]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 361          362     11   12  1977        1         DS   F             51.0
# 557          558      1    9  1978        1         DS   F             49.0
# 646          647      2   20  1978        1         DS   F             52.0
# 724          725      3   13  1978        1         DS   F              NaN
# 813          814      4   10  1978        1         DS   M             55.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 33224      33225     12   15  2001        1         NL   M             34.0
# 33738      33739      4   16  2002        1         NL   M             34.0
# 33949      33950      5   15  2002        1         NL   M             30.0
# 33950      33951      5   15  2002        1         NL   F             30.0
# 35198      35199     12    7  2002        1         NL   F             28.0
#
#        weight  weight_kg
# 361     121.0      0.121
# ...

# %%
plot1guys = surveys_df["plot_id"] == 1
surveys_df[plot1guys & (surveys_df["weight"]> 75)]
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 361          362     11   12  1977        1         DS   F             51.0
# 557          558      1    9  1978        1         DS   F             49.0
# 646          647      2   20  1978        1         DS   F             52.0
# 724          725      3   13  1978        1         DS   F              NaN
# 813          814      4   10  1978        1         DS   M             55.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 33224      33225     12   15  2001        1         NL   M             34.0
# 33738      33739      4   16  2002        1         NL   M             34.0
# 33949      33950      5   15  2002        1         NL   M             30.0
# 33950      33951      5   15  2002        1         NL   F             30.0
# 35198      35199     12    7  2002        1         NL   F             28.0
#
#        weight  weight_kg
# 361     121.0      0.121
# ...

# %%
plot1guys[plot1guys == True]
# Out:
# 5        True
# 7        True
# 8        True
# 77       True
# 79       True
#          ...
# 35388    True
# 35389    True
# 35390    True
# 35391    True
# 35392    True
# Name: plot_id, Length: 1995, dtype: bool

# %%
surveys_df.sort_values("weight")
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 9908        9909      1   20  1985       15         RM    F             15.0
# 4289        4290      4    6  1981        4         PF  NaN              NaN
# 9793        9794      1   19  1985       24         RM    M             16.0
# 9789        9790      1   19  1985       16         RM    F             16.0
# 5345        5346      2   22  1982       21         PF    F             14.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35530      35531     12   31  2002       13         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight  weight_kg
# ...

# %%
surveys_df.sort_values("weight", ascending=False).head()
# Out:
#        record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 33048      33049     11   17  2001       12         NL   M             33.0
# 12870      12871      5   28  1987        2         NL   M             32.0
# 15458      15459      1   11  1989        9         NL   M             36.0
# 2132        2133     10   25  1979        2         NL   F             33.0
# 12728      12729      4   26  1987        2         NL   M             32.0
#
#        weight  weight_kg
# 33048   280.0      0.280
# 12870   278.0      0.278
# 15458   275.0      0.275
# 2132    274.0      0.274
# 12728   270.0      0.270

# %%
surveys_df.sort_values("weight", ascending=False).head()[['month','day','year']]
# Out:
#        month  day  year
# 33048     11   17  2001
# 12870      5   28  1987
# 15458      1   11  1989
# 2132      10   25  1979
# 12728      4   26  1987
